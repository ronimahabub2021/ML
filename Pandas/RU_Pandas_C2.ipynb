# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Screen Time Data.csv')

# %%
df.head()
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
df.loc[0:5]
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
# 5      5  04/22/19     Monday                 189                 68
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
# 5                      0      9             3                   4
#
# ...

# %%
df.iloc[0:5]
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
dic={
    'num1':[1,2,3,4],
    'num2':[5,6,7,8]
}

# %%
df1=pd.DataFrame(dic)

# %%
df1
# Out:
#    num1  num2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %%
df1['num3']=[9,10,11,12]

# %%
df1
# Out:
#    num1  num2  num3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
df1.loc[len(df1)]=[1,1,1]

# %%
df1
# Out:
#    num1  num2  num3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12
# 4     1     1     1

# %%
df1.drop(['num1','num3'],axis=1,inplace=True)

# %%
df1
# Out:
#    num2
# 0     5
# 1     6
# 2     7
# 3     8
# 4     1

# %%
df1
# Out:
#    num2
# 0     5
# 1     6
# 2     7
# 3     8
# 4     1

# %%
df.head()
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
# 3      3  04/20/19   Saturday                 101                 69
# 4      4  04/21/19     Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
df[(df['Week Day']=='Friday') | (df['Productivity']>=15)]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 2       2  04/19/19     Friday                 112                 52
# 7       7  04/24/19  Wednesday                 135                 98
# 8       8  04/25/19   Thursday                  52                 25
# 9       9  04/26/19     Friday                 198                 76
# 16     16  05/03/19     Friday                  91                 64
# 20     20  05/07/19    Tuesday                 110                 70
# 21     21  05/08/19  Wednesday                 122                 53
# 22     22  05/09/19   Thursday                  96                 42
# 23     23  05/10/19     Friday                 161                 93
# 27     27  05/14/19    Tuesday                  88                 41
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fdef6cc3-1226-43be-8348-9c2aa050bb6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdef6cc3-1226-43be-8348-9c2aa050bb6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2=pd.read_csv('sample missing data.csv')

# %%
df2
# Out:
#    ID     Name   Age   Salary Department
# 0   1     John  25.0  50000.0         IT
# 1   2    Emily  30.0      NaN         HR
# 2   3  Michael  35.0  60000.0    Finance
# 3   4    Sarah   NaN  45000.0  Marketing
# 4   5    David  40.0  55000.0        NaN
# 5   6     Anna  28.0  48000.0         IT
# 6   7    James  33.0      NaN    Finance
# 7   8    Linda  29.0  52000.0         HR
# 8   9   Robert   NaN  58000.0         IT
# 9  10  Jessica  27.0  47000.0  Marketing

# %%
df2.isnull().sum()
# Out:
# ID            0
# Name          0
# Age           2
# Salary        2
# Department    1
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         8 non-null      float64
#  3   Salary      8 non-null      float64
#  4   Department  9 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 532.0+ bytes

# %%
df2
# Out:
#    ID     Name   Age   Salary Department
# 0   1     John  25.0  50000.0         IT
# 1   2    Emily  30.0      NaN         HR
# 2   3  Michael  35.0  60000.0    Finance
# 3   4    Sarah   NaN  45000.0  Marketing
# 4   5    David  40.0  55000.0        NaN
# 5   6     Anna  28.0  48000.0         IT
# 6   7    James  33.0      NaN    Finance
# 7   8    Linda  29.0  52000.0         HR
# 8   9   Robert   NaN  58000.0         IT
# 9  10  Jessica  27.0  47000.0  Marketing

# %%
df2.fillna(0,inplace=True)

# %%
df2.dropna(inplace=True)

# %%
df2.isnull().sum()
# Out:
# ID            0
# Name          0
# Age           0
# Salary        0
# Department    0
# dtype: int64

# %%
df2
# Out:
#    ID     Name   Age   Salary Department
# 0   1     John  25.0  50000.0         IT
# 2   3  Michael  35.0  60000.0    Finance
# 5   6     Anna  28.0  48000.0         IT
# 7   8    Linda  29.0  52000.0         HR
# 9  10  Jessica  27.0  47000.0  Marketing

# %%
files.upload()
# Out:
#      <input type="file" id="files-c1dcd08d-b707-4da2-ad21-eca47f7643b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1dcd08d-b707-4da2-ad21-eca47f7643b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df3=pd.read_csv('sample missing data.csv')

# %%
df3
# Out:
#    ID     Name   Age   Salary Department
# 0   1     John  25.0  50000.0         IT
# 1   2    Emily  30.0      NaN         HR
# 2   3  Michael  35.0  60000.0    Finance
# 3   4    Sarah   NaN  45000.0  Marketing
# 4   5    David  40.0  55000.0        NaN
# 5   6     Anna  28.0  48000.0         IT
# 6   7    James  33.0      NaN    Finance
# 7   8    Linda  29.0  52000.0         HR
# 8   9   Robert   NaN  58000.0         IT
# 9  10  Jessica  27.0  47000.0  Marketing

# %%
dic3={
    'Age':df3['Age'].mean(),
    'Salary':df3['Salary'].median(),
    'Department': df3['Department'].mode().iloc[0]#iloc
}
df3.fillna(dic3,inplace=True)

# %%
df3
# Out:
#    ID     Name     Age   Salary Department
# 0   1     John  25.000  50000.0         IT
# 1   2    Emily  30.000  51000.0         HR
# 2   3  Michael  35.000  60000.0    Finance
# 3   4    Sarah  30.875  45000.0  Marketing
# 4   5    David  40.000  55000.0         IT
# 5   6     Anna  28.000  48000.0         IT
# 6   7    James  33.000  51000.0    Finance
# 7   8    Linda  29.000  52000.0         HR
# 8   9   Robert  30.875  58000.0         IT
# 9  10  Jessica  27.000  47000.0  Marketing

# %%
# !ls
# Out:
#  sample_data  'sample missing data (1).csv'  'sample missing data.csv'	'Screen Time Data.csv'

# %%
df3[['Age']].corr()
# Out:
#      Age
# Age  1.0

# %%
# !pip install ydata_profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 81.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=43a02fe316bedd62f3b3c2dc8e8c7146570d7f9449829728b95acc736c114eca
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile=ProfileReport(df3,title='Pandas Profiling Report',explorative=True)

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-02-22 12:29:35.388719&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
